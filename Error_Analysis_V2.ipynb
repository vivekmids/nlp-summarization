# %%
import pandas as pd
import numpy as np 
import matplotlib as plt
from ast import literal_eval

# %%
# Forward 600 
# I don't have the history of the loss 

forward_600_adam_beam = pd.read_csv('forward_60_beam_inf.csv', converters = {"gen_summary": literal_eval})
forward_600_adam_greedy = pd.read_csv('forward_600_inf_decode.csv', converters = {"gen_summary": literal_eval})

# %%
type(forward_600_adam_beam['gen_summary'][0])
# Out:
# list

# %%
# rmsprop forward 
# from notebook forwards_inf notebook, loss for rmsprop generally does continue going down 

# General notes from looking at our model run logs (https://docs.google.com/spreadsheets/d/1iZgiEHaOLM195GCsnep5PpaZMOKRONvqnmuYVHHMZ6Q/edit#gid=271452635)
# 1. rmsprop did not necessarily give much of an improvement in rouge scores, 
# however given loss function, it's possible that we could have gotten an improved model with more epochs 

# 2. overall, it looks like beam search almost always give higher precision but lower recall than greedy 

#rms_forward_greedy = pd.read_csv('')
# I had forgotten to download the weights and could not rerun for the decoding sequences...

rms_forward_beam = pd.read_csv('testset_decoded_beam_exp7.csv', converters = {"gen_summary": literal_eval})

# %%
# rmwprop backward 
# from notebook backwards_inf notebook, loss for rmsprop generally does continue going down 
rms_backward_greedy = pd.read_csv('testset_decodedseq_exp8.csv', converters = {"gen_summary": literal_eval})
rms_backward_beam = pd.read_csv('beam_exp8.csv', converters = {'gen_summary': literal_eval})

# %%
# Comparison of lengths of outputs for beam vs. greedy 

sub1 = pd.DataFrame([pd.Series(forward_600_adam_beam['gen_summary'].apply(lambda x: len(x))),pd.Series(['generated']*len(forward_600_adam_beam))]).T
sub1.columns = ['gen_summary_len','type'] 

sub2 = pd.DataFrame([pd.Series(forward_600_adam_beam['ref_summary'].apply(lambda x: len(x))),pd.Series(['reference']*len(forward_600_adam_beam))]).T
sub2.columns = ['gen_summary_len','type'] 

len_gen_summary = pd.concat([sub1,sub2], axis=0).reset_index(drop=True)
len_gen_summary['gen_summary_len']=len_gen_summary['gen_summary_len'].astype(float)

# %%
lengths = pd.DataFrame()

# %%
lengths['Generated'] = forward_600_adam_beam['gen_summary'].apply(len)

# %%
lengths['Reference'] = forward_600_adam_beam['ref_summary'].apply(literal_eval).apply(len)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize = (10,10))
sns.boxplot( data=lengths, ax=ax).set_title('Forward 600 units; Length of Generated Summaries')
plt.ylabel('Length of Summaries')
plt.show()
# not much of a significant difference between lengths 
# although it looks like greedy search tends to have a larger range of lengths in the generated summaries

# %%
fig, ax = plt.subplots(figsize = (10,8))

sns.distplot(lengths['Generated'], ax=ax)
sns.distplot(lengths['Reference'],ax=ax).set_title('Forward 600 units; Length of Generated Summaries')

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
forward_600_adam_beam.shape
# Out:
# (10000, 6)

# %%
# let's see this with backward 


sub2 = pd.DataFrame([pd.Series(rms_backward_greedy['gen_summary'].apply(lambda x: len(x))),pd.Series(['greedy']*len(rms_backward_greedy))]).T
sub2.columns = ['gen_summary_len','type'] 

sub1 = pd.DataFrame([pd.Series(rms_backward_beam['gen_summary'].apply(lambda x: len(x))),pd.Series(['beam']*len(rms_backward_beam))]).T
sub1.columns = ['gen_summary_len','type'] 

len_gen_summary = pd.concat([sub1,sub2], axis=0).reset_index(drop=True)
len_gen_summary['gen_summary_len']=len_gen_summary['gen_summary_len'].astype(float)

# %%
fig, ax = plt.subplots(figsize = (10,10))
sns.boxplot(x='type', y='gen_summary_len', data=len_gen_summary, ax=ax).set_title('RMSProp Backwards: Length of Generated Summaries')
plt.show()

# %%
# Let's take a look at some of the summaries 

import pickle 

from sklearn.model_selection import train_test_split

# %%
clean_data = pickle.load( open("cleandata.pkl", "rb" ) )

# %%
x_data = clean_data['text'] 
y_data = clean_data['headline']

# %%
x_train, x_test_temp, y_train, y_test_temp = train_test_split(x_data, y_data, 
                                                            test_size=0.3, random_state=0) 
x_dev, x_test, y_dev, y_test = train_test_split(x_test_temp, y_test_temp, 
                                                            test_size=0.33, random_state=0)

# %%
# create index for easy reference 
x_test_series = x_test.reset_index(drop=True)
y_test_series = y_test.reset_index(drop=True)

# %%
# take a look at some of the samples 
for i in range(4003, 4109): 
    print('==============='+str(i)+'===================')
    print('======================================')
    print('--Original text: '+' '.join(x_test_series[i]))
    print('--Original summary: '+' '.join(y_test_series[i]))
    print('---------------------------------------')
    print('>>Forwards, hidden 600, adam and BEAM<<: '+' '.join(forward_600_adam_beam['gen_summary'][i]))
    print('>>Forwards, hidden 600, adam and GREEDY<<: '+' '.join(forward_600_adam_greedy['gen_summary'][i]))
    print('>>Forwards, rmsprop and BEAM<<: '+' '.join(rms_forward_beam['gen_summary'][i]))
    print('>>Backwards, rmsprop and BEAM<<: '+' '.join(rms_backward_beam['gen_summary'][i]))
    print('>>Backwards: rmsprop and GREEDY<<: '+' '.join(rms_backward_greedy['gen_summary'][i]))
# Out:
# ===============4003===================
# ======================================
# --Original text: if you are having a hard time penning your speech , consider turning to famous acceptance speeches for ideas on how and how not to proceed . modern history is full of examples of great and terrible acceptance speeches that can be used as inspiration . just a few notable examples are listed below as a positive example , consider jimmy valvano s phenomenal acceptance speech at the espy awards . just eight weeks before his premature death from cancer , the famed college basketball coach delivered an immensely moving speech to an ecstatic standing ovation from the crowd . as an example of what not to do , consider hilary swank s oscar acceptance speech for boys do not cry in . swank accepted her award gratefully , doling out thanks to all of her supporters , with the major exception of her husband , whom the cameras famously caught crying tears of joy during swank s speech . as an oddball example , consider joe pesci’s oscar acceptance speech . after taking the podium at the oscars for his work in goodfellas , pesci said simply , it is my privilege . thank you . pesci was both praised and lampooned for his five word speech .
# --Original summary: look for inspiration from the greats .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: give her a nickname .
# >>Forwards, hidden 600, adam and GREEDY<<: have a good personality
# >>Forwards, rmsprop and BEAM<<: be aware of the role of the conversation .
# >>Backwards, rmsprop and BEAM<<: understand the difference between the two and the .
# >>Backwards: rmsprop and GREEDY<<: understand the difference between a and a
# ===============4004===================
# ======================================
# --Original text: add texture and light or “shiny” areas with a white pencil . use the white pencil in diagonal strokes to develop the background . add more shadowing under your objects , if desired , with black and or light blue . for example , define the pores of a lemon with bits of white .
# --Original summary: make highlights and deepen shadows .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: create a simple sketch .
# >>Forwards, hidden 600, adam and GREEDY<<: add the darker color
# >>Forwards, rmsprop and BEAM<<: add white and white .
# >>Backwards, rmsprop and BEAM<<: add details .
# >>Backwards: rmsprop and GREEDY<<: add details to the outline of the drawing
# ===============4005===================
# ======================================
# --Original text: you must familiarize yourself with and abide by subtitling best practices . you can find a list of best practices at http www . ted . com participate translate guidelines h subtitling . some important ones to be aware of include putting the proper number of lines and characters in each subtitle . making sure the reading speed for each line is not too fast or too slow . compressing the written material while preserving the meaning .
# --Original summary: familiarize yourself with best practices .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: learn the terminology .
# >>Forwards, hidden 600, adam and GREEDY<<: use the reading material
# >>Forwards, rmsprop and BEAM<<: follow the rules .
# >>Backwards, rmsprop and BEAM<<: read the rules .
# >>Backwards: rmsprop and GREEDY<<: read the rules
# ===============4006===================
# ======================================
# --Original text: most countries or customs unions have central banks that provide information on their currency . if you are looking for information about elements such as specific placement of face or back plate numbers or even want to see up close examples of how to review standard authentication features , you can draw upon the resources that central banks or currency issuers provide .
# --Original summary: use central bank resources .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: look for a bank account .
# >>Forwards, hidden 600, adam and GREEDY<<: check out the resources available online
# >>Forwards, rmsprop and BEAM<<: look at the features of the website .
# >>Backwards, rmsprop and BEAM<<: look for a bank .
# >>Backwards: rmsprop and GREEDY<<: look for a bank with a credit union
# ===============4007===================
# ======================================
# --Original text: your child needs to observe good behavior to know what it looks like . no matter how old your child is , they will notice how you respond and behave in all kinds of situations . make sure that you are modeling the kinds of behavior that you want your child to display . for example , if you want your child to use good manners , then make sure that you model this behavior for your child . this might be as simple as saying “please” and “thank you , ” or waiting patiently in line at the grocery store .
# --Original summary: model good behavior .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: model good behavior .
# >>Forwards, hidden 600, adam and GREEDY<<: be clear about what you want your child to do
# >>Forwards, rmsprop and BEAM<<: be clear about your child s behavior .
# >>Backwards, rmsprop and BEAM<<: be patient .
# >>Backwards: rmsprop and GREEDY<<: model behavior
# ===============4008===================
# ======================================
# --Original text: a hard disk is built to store and access the large amounts of files that you want to preserve in your computer . it stores the songs , files , movies and application files you have downloaded from the network . day after day , the massive amounts of files can dramatically slow down your computer to a crawl and lead to the sluggish system performance , spyware attack and serious data loss . use the disk cleanup utility to help you keep the disk space clean and safe , and speed up windows xp easily and quickly . windows xp comes with disk cleanup utility that is built to offer you absolutely helpful service to clean out the system and application localization resources , os temp files , video format files in your hard disk which dramatically slow down your computer .
# --Original summary: keep your disk safe and clean .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: clean up .
# >>Forwards, hidden 600, adam and GREEDY<<: clean up your disks
# >>Forwards, rmsprop and BEAM<<: clean up your computer .
# >>Backwards, rmsprop and BEAM<<: clean up .
# >>Backwards: rmsprop and GREEDY<<: clean up your disk
# ===============4009===================
# ======================================
# --Original text: there should be at least inch . cm of fabric outside of the embroidery hoop .
# --Original summary: put the sheer fabric in an embroidery hoop , making sure that the fabric is smooth and pulled tightly .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: cut the lace .
# >>Forwards, hidden 600, adam and GREEDY<<: cut the lace
# >>Forwards, rmsprop and BEAM<<: cut a piece of fabric .
# >>Backwards, rmsprop and BEAM<<: cut the fabric .
# >>Backwards: rmsprop and GREEDY<<: cut a piece of fabric
# ===============4010===================
# ======================================
# --Original text: if you are nervous , you may feel overwhelmed . push through the anxiety and pay attention to their response . try not to color their response with your own emotions . let them speak as long as they need to , and pay attention . active listening shows your friend that you really do care about them . give them the courtesy to speak because you love them , even if their answer is disappointing .
# --Original summary: listen to their response .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: listen .
# >>Forwards, hidden 600, adam and GREEDY<<: listen to your friend
# >>Forwards, rmsprop and BEAM<<: listen actively .
# >>Backwards, rmsprop and BEAM<<: listen .
# >>Backwards: rmsprop and GREEDY<<: listen to your child
# ===============4011===================
# ======================================
# --Original text: collaborate on projects , and encourage them to look after their mental health . if you see an autistic person feeling bad about themselves , say a few encouraging words or drop them a kind note . boycotting autism speaks is a movement focused on supporting autistics . reach out , accept them as they are , and show them that you care . autistic advocates may have trouble reading their own emotions . if you noticed that they are becoming over stressed with activism , gently suggest a break to stim or do something fun . look out for the autistic people in your life , at all ages . even if young children are kept away from autism speaks , they may still absorb negative attitudes about autism from the people around them . remind them that you love and value them .
# --Original summary: support those around you , especially the autistic people who need it .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: be patient .
# >>Forwards, hidden 600, adam and GREEDY<<: let them know that they are autistic
# >>Forwards, rmsprop and BEAM<<: be patient .
# >>Backwards, rmsprop and BEAM<<: be patient .
# >>Backwards: rmsprop and GREEDY<<: recognize that autistic people may not be autistic
# ===============4012===================
# ======================================
# --Original text: this will be the shortest cutter on the chain . if all of the cutters seem to be the same length , you may start anywhere . the main concern is that you file each cutter so that the flat edge on top of each cutter is very nearly the same length . that way each will slice away the same amount of wood as they pass through the kerf of your cut . it also may help to mark the first tooth you file with a dab of paint or a permanent marker so you will be sure of where you started .
# --Original summary: locate the leading cutter as your starting point .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: cut a notch in the middle of the cutter .
# >>Forwards, hidden 600, adam and GREEDY<<: cut the first tooth
# >>Forwards, rmsprop and BEAM<<: cut a circle out of the circle .
# >>Backwards, rmsprop and BEAM<<: cut the wood .
# >>Backwards: rmsprop and GREEDY<<: cut the wood to the desired length
# ===============4013===================
# ======================================
# --Original text: breastfeeding pillows can be a great tool , but they do not work for every mother . sometimes , a breastfeeding pillow can result in your baby having difficulty latching . some babies do not take to breastfeeding and prefer to be held , resulting in them becoming fussy or difficult to nurse when using the pillow . nursing pillows are bulky and can be difficult to take from place to place . some others also report having to lean over the pillows and experiencing back aches because of this . remember , a nursing pillow is designed to provide you added comfort . some women find the pillow to be helpful to them and their babies , but if a breastfeeding pillow causes you discomfort it is not a necessity . old fashioned breastfeeding is fine if you do not feel comfortable with a breastfeeding pillow .
# --Original summary: understand the pillow is not for everyone .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: choose the right pillow .
# >>Forwards, hidden 600, adam and GREEDY<<: provide a comfortable pillow
# >>Forwards, rmsprop and BEAM<<: get a pillow .
# >>Backwards, rmsprop and BEAM<<: find a comfortable position .
# >>Backwards: rmsprop and GREEDY<<: consider your comfort zone
# ===============4014===================
# ======================================
# --Original text: make sure that the tortilla overlaps the edges of the bowl .
# --Original summary: place your flour tortilla into a bowl .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: spread the mixture across the bottom of the tortilla .
# >>Forwards, hidden 600, adam and GREEDY<<: spread the mixture across the bottom of the tortilla
# >>Forwards, rmsprop and BEAM<<: pour the mixture into a bowl .
# >>Backwards, rmsprop and BEAM<<: place the tortilla on the tortilla .
# >>Backwards: rmsprop and GREEDY<<: sprinkle the tortilla with the tortilla
# ===============4015===================
# ======================================
# --Original text: you have had access to them all year round . just why do you need to take them camping the laptop risks being dropped , getting dirty and having water soaked all over it – ditto the ipad and maybe even the portable music player . as for a dvd player in the wilds by this stage , it is not so much camping as trying to put up with the experience ! get wild and leave the electronic gear at home . rediscover conversations , story telling , drawing in the sand soil , and stargazing . none of these activities require complex gear . a cell phone for safety is okay but turn it off . it is out of bounds for games , work emails , and internet access unless you are looking up how to put up your tent . a camera is probably the one exception documenting the beauty of all you see and the happiness and tribulations of your fellow camp companions is definitely worthwhile .
# --Original summary: consider banning the electronic gadgets .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: be creative .
# >>Forwards, hidden 600, adam and GREEDY<<: use technology to your advantage
# >>Forwards, rmsprop and BEAM<<: get active .
# >>Backwards, rmsprop and BEAM<<: be prepared .
# >>Backwards: rmsprop and GREEDY<<: take care of your body
# ===============4016===================
# ======================================
# --Original text: if you are not crawling , then hunch over and put your hands out in front of you . try to hold your fingers as if they were mangled in an accident .
# --Original summary: crawl fast .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: keep your hands on your hands .
# >>Forwards, hidden 600, adam and GREEDY<<: hold your hands in your hands
# >>Forwards, rmsprop and BEAM<<: keep your hands on your hands .
# >>Backwards, rmsprop and BEAM<<: keep your hands behind your back .
# >>Backwards: rmsprop and GREEDY<<: keep your hands behind your hands
# ===============4017===================
# ======================================
# --Original text: follow the slipstitch with a half double crochet stitch . the half double crochet stitch is a bit more complex than a slipstitch , but it is easy after you do it a few times . to do an hdc stitch , loop the yarn over the hook , then insert the hook through the next stitch . then , loop the yarn over the hook again and pull through the first loop . then , loop the yarn over again and pull the hook through all three stitches that are on the hook .
# --Original summary: use a half double crochet hdc stitch next .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: make a single crochet .
# >>Forwards, hidden 600, adam and GREEDY<<: make a double crochet
# >>Forwards, rmsprop and BEAM<<: double crochet into the center .
# >>Backwards, rmsprop and BEAM<<: double crochet across the first round .
# >>Backwards: rmsprop and GREEDY<<: double crochet across the first round
# ===============4018===================
# ======================================
# --Original text: note that yelp is not available in some countries .
# --Original summary: login to yelp with your existing credentials or create a new account .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: type in the name of the business .
# >>Forwards, hidden 600, adam and GREEDY<<: click on the link that reads you want to add to your profile
# >>Forwards, rmsprop and BEAM<<: make sure that you have the correct type of website you are interested in .
# >>Backwards, rmsprop and BEAM<<: click the search button .
# >>Backwards: rmsprop and GREEDY<<: click the search button
# ===============4019===================
# ======================================
# --Original text: you can meet people in your area who are also doing the diet by joining a local support group . if there are no support groups in your area created for people who are doing the raw food diet , consider starting one up ! just having a few people to lean on during your adjustment period can make a tremendous difference in your ability to stay on track . people who share the same goal as you will help you keep to your diet and will also offer an excellent example showing you the benefits of what you are doing .
# --Original summary: become friends with other people who are on the raw food diet .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: join a support group .
# >>Forwards, hidden 600, adam and GREEDY<<: join a support group
# >>Forwards, rmsprop and BEAM<<: join a support group .
# >>Backwards, rmsprop and BEAM<<: find a support group .
# >>Backwards: rmsprop and GREEDY<<: meet with a support group
# ===============4020===================
# ======================================
# --Original text: add something to your life . . . your existence . you are going to be eliminating something very central to your existence . prepare for that , by adding to your life . find a different hobby other than baking those sweets exercise volunteer
# --Original summary: take care of yourself . . . first .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: find a hobby .
# >>Forwards, hidden 600, adam and GREEDY<<: make a list of things you love
# >>Forwards, rmsprop and BEAM<<: do things you love .
# >>Backwards, rmsprop and BEAM<<: do something you enjoy .
# >>Backwards: rmsprop and GREEDY<<: do something that you enjoy
# ===============4021===================
# ======================================
# --Original text: a username with three or more numbers at the end is probably an automated bot . particularly if you see multiple reviews for the same product from reviewers with usernames like this , you will not be able to trust these reviews .
# --Original summary: scrutinize the username .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: go to the company s website .
# >>Forwards, hidden 600, adam and GREEDY<<: go to the company s website
# >>Forwards, rmsprop and BEAM<<: look for reviews .
# >>Backwards, rmsprop and BEAM<<: check the email .
# >>Backwards: rmsprop and GREEDY<<: use the internet to create a user account
# ===============4022===================
# ======================================
# --Original text: your website should be a detailed advertisement of your business that affords customers the convenience of getting all the required information without having to go through the trouble of making telephone calls or email inquiries . provide detailed information about your van and all the packages you can offer . make sure your website clearly displays the costs , time , and hours of operation of each job as well . add pictures of your van , yourself , and any other employees to help your customers get to know your company .
# --Original summary: set up your website with plenty of details .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: create a website .
# >>Forwards, hidden 600, adam and GREEDY<<: include your business information
# >>Forwards, rmsprop and BEAM<<: develop a website .
# >>Backwards, rmsprop and BEAM<<: advertise your business .
# >>Backwards: rmsprop and GREEDY<<: advertise your business
# ===============4023===================
# ======================================
# --Original text: go to the chrome store and search for tampermonkey . then click on add to chrome . tampermonkey is a popular tool used to customize the way a web page displays or behaves .
# --Original summary: download the tampermonkey extension .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: open the chrome webstore .
# >>Forwards, hidden 600, adam and GREEDY<<: open the chrome webstore
# >>Forwards, rmsprop and BEAM<<: open chrome .
# >>Backwards, rmsprop and BEAM<<: open chrome .
# >>Backwards: rmsprop and GREEDY<<: search for chrome chrome chrome
# ===============4024===================
# ======================================
# --Original text: when you have found two cards that are a match , set that pair aside so that your game board becomes smaller . continue playing until every card has been turned over and you have created matches for each game piece . when you are finished playing , you can simply shuffle your cards and redistribute them to create your game board and play again .
# --Original summary: set aside pairs .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: play the game .
# >>Forwards, hidden 600, adam and GREEDY<<: set up the game
# >>Forwards, rmsprop and BEAM<<: play cards .
# >>Backwards, rmsprop and BEAM<<: continue playing until you reach the top .
# >>Backwards: rmsprop and GREEDY<<: continue playing until you have finished
# ===============4025===================
# ======================================
# --Original text: on a hot griddle , cook the pancakes of your desired size until golden brown on each side . lay each pancake on a plate .
# --Original summary: cook the pancakes .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: cook the pancakes .
# >>Forwards, hidden 600, adam and GREEDY<<: cook the pancakes
# >>Forwards, rmsprop and BEAM<<: cook the pancakes .
# >>Backwards, rmsprop and BEAM<<: cook the pancakes .
# >>Backwards: rmsprop and GREEDY<<: cook the pancakes
# ===============4026===================
# ======================================
# --Original text: a person’s identity is especially susceptible to theft in the months following death . according to the internal revenue service irs , the problem is increasing because identity information about the recently deceased is so easy to get . the government publishes the names and social security numbers of the recently deceased on the social security administration’s website in order to prevent welfare fraud . but identity thieves need only to download this excel file from the website . some genealogy websites publish social security numbers and maiden names of the deceased . it can take up to a year to settle the affairs of a person who has died . during this time , bills continue to come in and creditors are notified of the death . identity thieves think a few extra credit card bills in the person’s name are not likely to get noticed .
# --Original summary: guard against identity theft if your spouse has died .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: wait for a response .
# >>Forwards, hidden 600, adam and GREEDY<<: collect the deceased s genealogy certificate
# >>Forwards, rmsprop and BEAM<<: search online .
# >>Backwards, rmsprop and BEAM<<: visit the social security website .
# >>Backwards: rmsprop and GREEDY<<: file a federal online
# ===============4027===================
# ======================================
# --Original text: this can also be done via email , or through a typed letter , depending on the kind of company you are applying to . a social media related or tech company might appreciate the ease and efficiency of an email , whereas a company with more old fashioned or traditional values would appreciate a letter . whatever form you use , the purpose of the letter is to remind the interviewer of what a strong candidate you are and why you are uniquely qualified for the job . if you interviewed by multiple people , you should send each of them a separate thank you letter . use the interviewer’s first name in the greeting and salutation only if you were told to do so during the interview otherwise , address the interviewer in a formal manner . after thanking the interviewer again for the opportunity to interview with the company , affirm your interest in the position and reiterate how you would be an asset to the company . add information that the interviewer might be interested in , or some useful information that the company could use profitably . this will help the interviewer to remember you , as most people follow up after a job interview with only information about themselves . close the letter with the valediction yours sincerely and proofread it thoroughly for grammar , spelling and punctuation . a poorly worded or misspelled thank you letter can be all it takes to disqualify you as a candidate .
# --Original summary: mail a more formal thank you letter .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: write a letter .
# >>Forwards, hidden 600, adam and GREEDY<<: write the body of the company
# >>Forwards, rmsprop and BEAM<<: prepare for the interview .
# >>Backwards, rmsprop and BEAM<<: write a brief introduction .
# >>Backwards: rmsprop and GREEDY<<: write a brief description of the essay
# ===============4028===================
# ======================================
# --Original text: make sure all the pieces have been accounted for and adjust their sizes or proportions as necessary . whenever you have matching pieces e . g . two shin plates , gauntlets , etc . , choose the nicer version and scrap the other one that way , you can use the nice one as the pattern for the other to keep your armor symmetrical . when you’re happy with your pieces , clean up and smooth out the lines , label both your original sketch and the corresponding pieces making note of any that will be duplicated , and cut all the shapes .
# --Original summary: finalize the template .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: make the pattern .
# >>Forwards, hidden 600, adam and GREEDY<<: make the pattern
# >>Forwards, rmsprop and BEAM<<: repeat the process for the other pieces .
# >>Backwards, rmsprop and BEAM<<: make your pattern .
# >>Backwards: rmsprop and GREEDY<<: make a pattern
# ===============4029===================
# ======================================
# --Original text: what do they do differently how do they do it why these and more are all questions you should ask yourself and apply . you do not have to do things single handedly . there are tons of things you can learn from . don t be afraid to develop your own ideas and opinions about your art form . besides knowing these things , you also have to put it into practice . stay after class to do this if you will . while the other people dance and you are waiting for your turn , instead of talking or drilling , ask yourself what you can do to be better , more beautiful , more artistic . . . whatever . know , then apply .
# --Original summary: analyze lead dancers principles , soloists from corps de ballet members background dancers in a company and students and see what makes them different .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: be original .
# >>Forwards, hidden 600, adam and GREEDY<<: learn to be more about your talents
# >>Forwards, rmsprop and BEAM<<: learn from your mistakes .
# >>Backwards, rmsprop and BEAM<<: be patient .
# >>Backwards: rmsprop and GREEDY<<: learn to be creative
# ===============4030===================
# ======================================
# --Original text: common side effects include fever or fatigue . you may notice a rash up to one month after the chickenpox vaccine is administered , and may experience soreness or swelling on the site where you received the vaccine shot . more serious , but very rare side effects include shock , thrombocytopenia blood disorder , seizures , inflammation of the brain encephalitis , guillain barré syndrome , and infection with chickenpox . additional serious but still rare side effects from the chickenpox vaccine include seizures , pneumonia , loss of balance , and severe allergic reactions . people who have received the chickenpox immunization may get a mild form of the virus and can still spread the disease to those who are not protected , but this too is rare . a high fever , behavioral changes , or an allergic reaction hives , swelling of the face or throat , arrhythmia , or dizziness should be reported to your doctor immediately . if the reaction is severe or the person experiences difficulty breathing , call for emergency services .
# --Original summary: watch for side effects .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: recognize the symptoms .
# >>Forwards, hidden 600, adam and GREEDY<<: recognize the symptoms of a septic illness
# >>Forwards, rmsprop and BEAM<<: seek medical attention if you experience severe symptoms .
# >>Backwards, rmsprop and BEAM<<: seek medical attention immediately .
# >>Backwards: rmsprop and GREEDY<<: seek medical attention if you have been experiencing symptoms
# ===============4031===================
# ======================================
# --Original text: this is important because they can provide you with criticism and things you did good . please be aware that they are not pros .
# --Original summary: practice in front of friends and family .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: if you are not sure that your child has a good reputation , do not be afraid to ask for their opinions .
# >>Forwards, hidden 600, adam and GREEDY<<: don t hesitate to ask for a job
# >>Forwards, rmsprop and BEAM<<: ask for help .
# >>Backwards, rmsprop and BEAM<<: ask your friends to help you .
# >>Backwards: rmsprop and GREEDY<<: if you are not able to talk to your friends , they are not a good time
# ===============4032===================
# ======================================
# --Original text: autoclaves use high temperature steam omitted at a high pressure over a certain period of time to sterilize medical objects . this works by killing the microorganisms through time , heat , steam , and pressure . there are different settings on an autoclave machine that work for different things . since you have bags of instruments , you should use the fast exhaust and dry cycle . this works best for wrapped items like instruments . autoclaving fast exhaust will also sterilize glassware .
# --Original summary: choose a cycle on the autoclave machine .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: use a autoclave .
# >>Forwards, hidden 600, adam and GREEDY<<: use a autoclave for a portable heater
# >>Forwards, rmsprop and BEAM<<: use a heat gun .
# >>Backwards, rmsprop and BEAM<<: use a humidifier .
# >>Backwards: rmsprop and GREEDY<<: choose the right temperature
# ===============4033===================
# ======================================
# --Original text: your baby will be delighted by your funny faces , and may try to imitate you if she can . making funny sounds , sticking out your tongue , or twisting your face into a funny shape will be entertaining for a baby . babies love to be talked to and have their attention focused on you . you are likely your newborn baby’s favorite toy .
# --Original summary: make your face entertaining .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: play with your newborn .
# >>Forwards, hidden 600, adam and GREEDY<<: keep your baby’s smiling smiling
# >>Forwards, rmsprop and BEAM<<: show your baby laugh .
# >>Backwards, rmsprop and BEAM<<: use your baby .
# >>Backwards: rmsprop and GREEDY<<: use your baby s body language
# ===============4034===================
# ======================================
# --Original text: research has shown that prolonged eye contact can increase feelings of attraction between two people . if you are trying to win her over , try looking into her eyes with a penetrating gaze . just keep in mind that she may break the gaze if she is not interested . if she is interested , she will most likely give you some encouraging looks and smiles , even if she takes her eyes away from yours now and then . if a long gaze does not seem appropriate yet or you are just too nervous to hold a long gaze , try giving her frequent , quick glances .
# --Original summary: gaze into her eyes .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: make eye contact .
# >>Forwards, hidden 600, adam and GREEDY<<: make eye contact
# >>Forwards, rmsprop and BEAM<<: make eye contact .
# >>Backwards, rmsprop and BEAM<<: make eye contact .
# >>Backwards: rmsprop and GREEDY<<: make eye contact
# ===============4035===================
# ======================================
# --Original text: having employees requires you to pay your employees , on time and correctly . you need a reliable payroll system that accounts for employee hours and pay rates . you must withhold the proper amounts for federal , state and local taxes , and deposit those as required with the taxing authorities . establish a consistent system for payment , whether weekly or bi weekly . for help with federal tax requirements , the irs has put out two publications , the employer’s tax guide , publication , and the employer’s supplemental tax guide , publication a . you can find both publications at the irs publications page , at www . irs . gov forms pubs .
# --Original summary: take care of payroll .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: create a budget .
# >>Forwards, hidden 600, adam and GREEDY<<: deduct the tax paid
# >>Forwards, rmsprop and BEAM<<: pay the filing fee .
# >>Backwards, rmsprop and BEAM<<: pay taxes .
# >>Backwards: rmsprop and GREEDY<<: pay taxes
# ===============4036===================
# ======================================
# --Original text: go south and then west until you find a waterfall . use waterfall and go west until you reach a fork . go south , then west until you find a cave . enter it .
# --Original summary: go to the southern part of the route near the dark grass and use surf .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: soar .
# >>Forwards, hidden 600, adam and GREEDY<<: go to the north of the mountain
# >>Forwards, rmsprop and BEAM<<: go to route .
# >>Backwards, rmsprop and BEAM<<: go to route .
# >>Backwards: rmsprop and GREEDY<<: go to the end of the cave
# ===============4037===================
# ======================================
# --Original text: a smile will help put your audience and you at ease .
# --Original summary: remember to smile !
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: smile .
# >>Forwards, hidden 600, adam and GREEDY<<: smile
# >>Forwards, rmsprop and BEAM<<: smile .
# >>Backwards, rmsprop and BEAM<<: smile .
# >>Backwards: rmsprop and GREEDY<<: smile
# ===============4038===================
# ======================================
# --Original text: you can file using a form ez , a , or . the form you file will depend on a variety of factors . consider the following form ez . this is the easiest to complete . generally , you can choose this form if you aren’t claiming dependents and your taxable income is less than , . however , you can’t choose ez if you are filing married filing separately . form a . you can use this form if your taxable income is less than , and you don’t itemize deductions . form . all others must use this form .
# --Original summary: choose the right form to file .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: fill out the form .
# >>Forwards, hidden 600, adam and GREEDY<<: fill out the form
# >>Forwards, rmsprop and BEAM<<: obtain form form .
# >>Backwards, rmsprop and BEAM<<: determine if you are eligible to file .
# >>Backwards: rmsprop and GREEDY<<: file your petition
# ===============4039===================
# ======================================
# --Original text: select , thick slices of bacon , and cut them crosswise into ¼ inch . centimeter wide strips . place the bacon into a large , heavy bottomed pot , then turn the heat up to medium . cook the bacon until it is lightly browned , then set it aside on a stack of paper towels so that it can drain .
# --Original summary: cut the bacon into thin strips , then cook it in a large , heavy bottomed pot over medium heat until it browns .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: cook the bacon .
# >>Forwards, hidden 600, adam and GREEDY<<: cook the bacon
# >>Forwards, rmsprop and BEAM<<: slice the bacon into bacon slices .
# >>Backwards, rmsprop and BEAM<<: cook the bacon .
# >>Backwards: rmsprop and GREEDY<<: cook the bacon
# ===============4040===================
# ======================================
# --Original text: instead of stressing yourself about why or how you got into or were on the receiving end of the problem , focus on solving rather than perpetuating the problem . acceptance can help by allowing you to just deal with the fact it has happened and now it is time to move upward and onward .
# --Original summary: accept things for what they are .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: practice forgiveness .
# >>Forwards, hidden 600, adam and GREEDY<<: accept responsibility
# >>Forwards, rmsprop and BEAM<<: recognize the problem .
# >>Backwards, rmsprop and BEAM<<: don t blame yourself .
# >>Backwards: rmsprop and GREEDY<<: accept your mistakes
# ===============4041===================
# ======================================
# --Original text: this will take you to a secret area where you can unlock wario .
# --Original summary: jump into the wario portrait .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: go to the pokémon center .
# >>Forwards, hidden 600, adam and GREEDY<<: tap the red button next to the option
# >>Forwards, rmsprop and BEAM<<: go to the home screen .
# >>Backwards, rmsprop and BEAM<<: go to route .
# >>Backwards: rmsprop and GREEDY<<: go to the menu
# ===============4042===================
# ======================================
# --Original text: it is important that you do not score the wall , as this will damage the wall and cause the paper to come off in small strips . specialized tools are available at your local hardware store . look for tools which have spur like wheels on them . these tools will perforate the wall with thousands of little dots , so that the dif can soak in . make sure you do a thorough job of perforating the wall . you will notice that areas with less perforation are harder to remove
# --Original summary: perforate the wall .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: check the wall .
# >>Forwards, hidden 600, adam and GREEDY<<: use a lightweight , lightweight , lightweight , lightweight , insulated free board
# >>Forwards, rmsprop and BEAM<<: use a sharp knife .
# >>Backwards, rmsprop and BEAM<<: remove the wall .
# >>Backwards: rmsprop and GREEDY<<: use a wall to remove the wall
# ===============4043===================
# ======================================
# --Original text: this is the best thing you can do to get more power on the ball quickly . you want your arms and knees to be slightly bent and loose , not tensed . work on swinging naturally and smoothly , avoiding jerky movements meant to hit the ball hard . remember , good mechanics and a smooth swing are more important than trying to force as much power on your swing as you can .
# --Original summary: relax your swing .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: swing your arms .
# >>Forwards, hidden 600, adam and GREEDY<<: swing your arms
# >>Forwards, rmsprop and BEAM<<: swing .
# >>Backwards, rmsprop and BEAM<<: keep your body straight .
# >>Backwards: rmsprop and GREEDY<<: keep your body straight
# ===============4044===================
# ======================================
# --Original text: but only do this as you have received a big fanbase . if you got the money already it is fine . try to find manufacturers to make shirts . this is only when you are getting known pretty well . if you would like to , try making a iphone app .
# --Original summary: sell merchandise .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: put on a pair of rubber bands .
# >>Forwards, hidden 600, adam and GREEDY<<: take a look at the money
# >>Forwards, rmsprop and BEAM<<: get a good idea .
# >>Backwards, rmsprop and BEAM<<: make sure you have all of your clothes .
# >>Backwards: rmsprop and GREEDY<<: get a band t shirts
# ===============4045===================
# ======================================
# --Original text: the point at which you decide to stop is up to you . there is no need to wait for orgasm or , indeed , to stop just because you have both come . there s no rule as to how quickly you should end the call after finishing . some people prefer ending the call as soon as their breathing has gone back to normal , whereas others prefer to stay on the line and chat . let your partner know how much you enjoyed yourself before you end the call .
# --Original summary: finish .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: end the call .
# >>Forwards, hidden 600, adam and GREEDY<<: the call
# >>Forwards, rmsprop and BEAM<<: stop when you are ready .
# >>Backwards, rmsprop and BEAM<<: call .
# >>Backwards: rmsprop and GREEDY<<: don t be afraid to say
# ===============4046===================
# ======================================
# --Original text: place small dab of the cream on the back or your hand or some other place . leave it on for as long as the box directs you to this will generally be two minutes . wash off the cream . if your skin is very red or irritated , it is probably best if you do not use the cream on your face . if it is only mildly red or there is no reaction , go ahead and use it !
# --Original summary: test your skin to see if the cream will cause irritation .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: apply the depilatory cream .
# >>Forwards, hidden 600, adam and GREEDY<<: spread the cream on your face
# >>Forwards, rmsprop and BEAM<<: use a cream cream cream .
# >>Backwards, rmsprop and BEAM<<: apply the cream .
# >>Backwards: rmsprop and GREEDY<<: apply the cream to your skin
# ===============4047===================
# ======================================
# --Original text: all good study begins with being set up in a suitable place where you can study without being distracted . this helps the retention of information with greater ease and gives you a mind s eye view of where you were when you learned the information , making it easier to recall the information . it really helps to avoid moving around study locations while studying , unless each of those locations is distinct to a subject and remains the same to that subject . for example , math study only on the library room , english study only at your home desk , etc .
# --Original summary: be well prepared .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: create a study space .
# >>Forwards, hidden 600, adam and GREEDY<<: study the study techniques
# >>Forwards, rmsprop and BEAM<<: find a place to study .
# >>Backwards, rmsprop and BEAM<<: choose a study space .
# >>Backwards: rmsprop and GREEDY<<: choose a study space
# ===============4048===================
# ======================================
# --Original text: your child may especially love clothes that are fun to stim in , and this can help them feel happy and calm . look at both opportunities built into the clothes , and big pockets where they can put stim toys and comfort objects . here are some ways autistic kids like to stim with clothes long skirts are fun for spinning . strings and zippers present fun fidgeting opportunities . fur is good for petting . chunky bracelets or bracelets with big beads can be twirled and spun in the hands . if your child is putting their clothes in their mouth , get them some chewy necklaces or bracelets from a special needs store . these can be found online as well .
# --Original summary: consider stimming opportunities .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: dress the child .
# >>Forwards, hidden 600, adam and GREEDY<<: dress the child
# >>Forwards, rmsprop and BEAM<<: give your child a look .
# >>Backwards, rmsprop and BEAM<<: wear clothing .
# >>Backwards: rmsprop and GREEDY<<: wear clothing
# ===============4049===================
# ======================================
# --Original text: keep the cutting on a paper towel away from direct sunlight , and check on the cut end regularly . the cut should dry out , making the new plant less susceptible to rot . stem cuttings can be planted after one or two days of drying . leaf cuttings undergo a more visible change , growing a callous over the cut surface . this can take anywhere from two to seven days . if a leaf shrivels significantly during this time , you may need to plant it early . this has a lower success rate , but the leaf may die if it dries out completely .
# --Original summary: let the cutting dry out in a lightly shaded location .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: propagate cacti from cuttings .
# >>Forwards, hidden 600, adam and GREEDY<<: propagate cacti in the cutting area
# >>Forwards, rmsprop and BEAM<<: monitor the plant .
# >>Backwards, rmsprop and BEAM<<: wait for the to dry .
# >>Backwards: rmsprop and GREEDY<<: wait for the to dry
# ===============4050===================
# ======================================
# --Original text: never risk playing games while your boss is on the loose . have confirmation that he or she will not be dropping by .
# --Original summary: check your boss’s schedule to ensure he or she is out of the office or in a meeting .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: if you do not want to play games , do not play games .
# >>Forwards, hidden 600, adam and GREEDY<<: play games
# >>Forwards, rmsprop and BEAM<<: don t play games .
# >>Backwards, rmsprop and BEAM<<: don t be afraid to do your best .
# >>Backwards: rmsprop and GREEDY<<: don t let your boss know that you are not the same
# ===============4051===================
# ======================================
# --Original text: begin by bouncing the ball off your thigh and catching it . repeat this process until you are able to control the direction of the ball and how high it goes with your thigh . switch to the other thigh and repeat the process .
# --Original summary: juggle with your thighs the way you would juggle with your feet .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: move your leg .
# >>Forwards, hidden 600, adam and GREEDY<<: practice the ball
# >>Forwards, rmsprop and BEAM<<: kick your ball .
# >>Backwards, rmsprop and BEAM<<: push your hips forward .
# >>Backwards: rmsprop and GREEDY<<: push your hips forward
# ===============4052===================
# ======================================
# --Original text: for instance , young nursery trees will sustain faster growth than older trees , deciduous trees are hardier than evergreens , and trees with shallow roots will adapt better than those with deep roots . ask the nursery for information before you decide what type of tree to purchase .
# --Original summary: consider the potential transplanting success of the type of tree .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: decide what kind of tree you want to grow .
# >>Forwards, hidden 600, adam and GREEDY<<: decide what kind of tree you want to grow
# >>Forwards, rmsprop and BEAM<<: choose a plant trees .
# >>Backwards, rmsprop and BEAM<<: consider the size of the tree .
# >>Backwards: rmsprop and GREEDY<<: select the right type of tree
# ===============4053===================
# ======================================
# ...
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: research local shelters .
# >>Forwards, hidden 600, adam and GREEDY<<: research local shelters
# >>Forwards, rmsprop and BEAM<<: research the laws of your state .
# >>Backwards, rmsprop and BEAM<<: check your local laws .
# >>Backwards: rmsprop and GREEDY<<: check your local laws
# ===============4093===================
# ======================================
# --Original text: not all bullying involves physical violence . verbal taunts can be just as damaging as physical attacks . watch for any unexplained or sudden changes in your child s behavior . a sudden withdrawal from friends or activities . this will often center on activities where the bully is present . for example , if your child suddenly does not want to go to baseball practice , there could be a bully on the team . sudden mood swings or aggression . sudden decline in grades at school . difficulty sleeping . nightmares or night terrors .
# --Original summary: look for emotional or psychological signs of bullying .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: watch for physical violence .
# >>Forwards, hidden 600, adam and GREEDY<<: watch for signs of violence
# >>Forwards, rmsprop and BEAM<<: recognize the signs of a child .
# >>Backwards, rmsprop and BEAM<<: recognize the bully .
# >>Backwards: rmsprop and GREEDY<<: recognize the bully
# ===============4094===================
# ======================================
# --Original text: if your parents say no or have certain reservations , try to understand their point of view . if you are willing to understand where your parents are coming from , they will return that respect . they will try to understand your perspective as well . genuinely listen to your parents reasons or concerns . they may be worried about violence in video games . they may worry about you wasting your time when you could be studying . many parents believe children are better off without video games . it is not uncommon for parents to have certain reservations . respond respectfully to their concerns . explain to them ways you will make sure those concerns do not become an issue . for example , say your parents are worried about the level of violence in video games . respond with something like , i definitely understand why that would be a concern for you . i would be open to allowing you to screen the games i pick . if there is anything you feel is inappropriate , i will go with a different game .
# --Original summary: try to understand your parents perspective .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: talk to your parents .
# >>Forwards, hidden 600, adam and GREEDY<<: talk to your parents
# >>Forwards, rmsprop and BEAM<<: ask your parents if they have their parents .
# >>Backwards, rmsprop and BEAM<<: talk to your parents .
# >>Backwards: rmsprop and GREEDY<<: talk to your parents
# ===============4095===================
# ======================================
# --Original text: the first way to deal with your cat’s feline pica is to cut off its access to the items it chews or eats the most . move plants to high shelves , hide wires and cords e . g . with plastic tubing and keep laundry tucked away in drawers or closets . if your cat has a habit of chewing bedclothes , keep it locked out of any bedrooms .
# --Original summary: move target items out of your cat’s reach .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: keep your cat out of reach .
# >>Forwards, hidden 600, adam and GREEDY<<: keep your cat away from chewing free items
# >>Forwards, rmsprop and BEAM<<: remove any items from your home .
# >>Backwards, rmsprop and BEAM<<: keep your house safe .
# >>Backwards: rmsprop and GREEDY<<: keep your cat safe
# ===============4096===================
# ======================================
# --Original text: for example , open itunes , click main menu edit preferences . . . , select the advanced tab . in the burning page , change the cd burner to tunepat cd rw .
# --Original summary: in the music playing software such as itunes , select tunepat virtual cd rw as the default cd burner for converting m p to virtual cd .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: select the cd you want to use .
# >>Forwards, hidden 600, adam and GREEDY<<: click on the icon of the cd
# >>Forwards, rmsprop and BEAM<<: open the cd menu .
# >>Backwards, rmsprop and BEAM<<: burn the cd .
# >>Backwards: rmsprop and GREEDY<<: burn the cd
# ===============4097===================
# ======================================
# --Original text: make sure the lights are off and blinds are closed . put rubber gloves on and open the container of emulsion and use the spatula to stir the chemical . measure ½ cup of chemical for a large screen and pour into the emulsion trough . disperse evenly so the chemical is stretching the entire width of the trough .
# --Original summary: mix and measure emulsion .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: pour the pesticide into the water .
# >>Forwards, hidden 600, adam and GREEDY<<: pour the pesticide into the water
# >>Forwards, rmsprop and BEAM<<: pour the mixture into the mixing bowl .
# >>Backwards, rmsprop and BEAM<<: place the bowl on the stove .
# >>Backwards: rmsprop and GREEDY<<: add the water to the bowl
# ===============4098===================
# ======================================
# --Original text: don’t just start going straight into the meat of your speech . people expect a small preamble , and it’s good to get your voice working first anyways . address the crowd and say good morning , good afternoon , whatever it may be . for example , say something like good morning afternoon night to the faculty , our trustees , and of course my classmates
# --Original summary: make sure you address everyone in the audience .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: start the conversation .
# >>Forwards, hidden 600, adam and GREEDY<<: speak to your audience
# >>Forwards, rmsprop and BEAM<<: start with a good note .
# >>Backwards, rmsprop and BEAM<<: say thank you .
# >>Backwards: rmsprop and GREEDY<<: thank your thank you
# ===============4099===================
# ======================================
# --Original text: pickpockets , especially those working in teams , rely on disorienting their victims with distractions so they won’t notice their pockets being picked . because of this , they love to prey on people who appear lost since they’re already disoriented , so act like you know exactly where you are , even if it’s a bluff . if you become lost casually note a landmark or cross street to get your bearings . then keep walking until you find a less crowded place where you can sit down , like a cafe or a park bench . stroll on in as if this is exactly where you were headed in the first place . order a coffee , take a seat , and wait a few minutes before checking your map , as if you’re just relaxing . if you have a smartphone , use that to find a map , since you could be looking up anything . otherwise , take your physical map out and study it casually , as if looking up something for later . once you know where you’re going , wait a little bit before heading on . cement the idea that you were just double checking something , not trying to figure out where you are .
# --Original summary: act like you know where you’re going .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: find a map .
# >>Forwards, hidden 600, adam and GREEDY<<: find a map
# >>Forwards, rmsprop and BEAM<<: get a map .
# >>Backwards, rmsprop and BEAM<<: find a place where you are going to go .
# >>Backwards: rmsprop and GREEDY<<: keep your distance
# ===============4100===================
# ======================================
# --Original text: make appropriate costumes for the people in each district . example a district tribute could wear a glittery crown and a district tribute could wear cow ears . costumes could be as simple as a hat or as big an overall costume . for chariots , you could use scooters , bikes , roller blades , etc .
# --Original summary: optional have a chariot ride !
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: accessorize .
# >>Forwards, hidden 600, adam and GREEDY<<: accessorize
# >>Forwards, rmsprop and BEAM<<: make a costume .
# >>Backwards, rmsprop and BEAM<<: choose the props .
# >>Backwards: rmsprop and GREEDY<<: choose the props
# ===============4101===================
# ======================================
# --Original text: paint over the imprinted design and paint to the edges of the pinboard .
# --Original summary: paint the polystyrene .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: paint the outside of the doormat .
# >>Forwards, hidden 600, adam and GREEDY<<: paint the outside of the stencil
# >>Forwards, rmsprop and BEAM<<: paint the design .
# >>Backwards, rmsprop and BEAM<<: paint the design .
# >>Backwards: rmsprop and GREEDY<<: paint the design
# ===============4102===================
# ======================================
# --Original text: be prepared for a strong taste . many people claim that the suicide shot does not taste great , which is understandable considering the name .
# --Original summary: knock it back .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: know what the name is .
# >>Forwards, hidden 600, adam and GREEDY<<: be careful with the petition
# >>Forwards, rmsprop and BEAM<<: make sure that you have a good time to do something .
# >>Backwards, rmsprop and BEAM<<: don t be afraid of the same way .
# >>Backwards: rmsprop and GREEDY<<: make sure you are not able to make the most of the same way you want to be
# ===============4103===================
# ======================================
# --Original text: financial portfolios are much different than portfolios demonstrating creative or professional abilities . build a stock portfolio or make a mutual funds portfolio by diversifying and investing wisely . construct a property portfolio . research various properties to determine which can produce positive cash flow . create a gold based wealth portfolio by learning about the best ways to invest in gold and precious metals .
# --Original summary: build a financial portfolio .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: build a portfolio .
# >>Forwards, hidden 600, adam and GREEDY<<: build a portfolio
# >>Forwards, rmsprop and BEAM<<: build a portfolio .
# >>Backwards, rmsprop and BEAM<<: invest in portfolio .
# >>Backwards: rmsprop and GREEDY<<: invest in portfolio
# ===============4104===================
# ======================================
# --Original text: in the mac os x v . . or earlier versions , you can go in the ‘printer’ menu to select ‘edit printer list’ . as soon as you do this , the printer list window appears soon . you can now select the ‘show printer list’ in the ‘view’ menu and then the ‘printer list window’ appears .
# --Original summary: browse printer menu .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: select hp laserjet .
# >>Forwards, hidden 600, adam and GREEDY<<: select hp laserjet
# >>Forwards, rmsprop and BEAM<<: select a printer .
# >>Backwards, rmsprop and BEAM<<: select the printer .
# >>Backwards: rmsprop and GREEDY<<: enable the printer
# ===============4105===================
# ======================================
# --Original text: hypertension , or high blood pressure , causes damage to cerebral blood vessels and the lining of the aorta , which can lead to the development of aneurysms . losing weight if you are overweight or obese can reduce your blood pressure . even losing pounds . kg makes a difference . get regular exercise . getting minutes a day of moderate physical exercise can help lower your blood pressure . limit alcohol . do not drink more than drinks per day for most women , for most men .
# --Original summary: watch your blood pressure .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: lose weight .
# >>Forwards, hidden 600, adam and GREEDY<<: maintain a healthy lifestyle
# >>Forwards, rmsprop and BEAM<<: exercise regularly .
# >>Backwards, rmsprop and BEAM<<: lose weight .
# >>Backwards: rmsprop and GREEDY<<: maintain healthy weight
# ===============4106===================
# ======================================
# --Original text: pool shock has high levels of chlorine that wipe out the algae and sanitize the pool . choose a powerful shock with around available chlorine , which is enough to handle tough algae and bacteria . follow the directions on the shock package to make sure you use the proper amount for the water in your pool . if you have a high amount of algae in your pool , you may have to treat it more than once to keep the algae from continuing to bloom . the water might look cloudy or dirty when you add the shock , but as the water runs through the filter it will begin to clean up .
# --Original summary: treat the pool with pool shock .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: submerge your pool .
# >>Forwards, hidden 600, adam and GREEDY<<: submerge your pool in the water
# >>Forwards, rmsprop and BEAM<<: use a pool pool .
# >>Backwards, rmsprop and BEAM<<: add water .
# >>Backwards: rmsprop and GREEDY<<: use a water pump to fill out the pool
# ===============4107===================
# ======================================
# --Original text: while the loose , potentially flea infested items are being washed , arm yourself with a vacuum and suck the flea life out of every surface , nook and cranny you can find . while you are doing this , send the pet s outside , or confine them to the bathroom , so that any fleas they are carrying will not jump onto the surface you just vacuumed . sticking a flea collar or broken up mothballs in the vacuum cleaner helps to kill off the buggers that you have sucked up so they cannot come back to haunt you . fleas mostly will not survive the vacuum , but you want to play it safe . focus on areas that do not get much exposure to sunlight fleas like humid and cool spots , anywhere that you find dried blood and feces flea debris , upholstered furniture , and crevices around baseboards and cabinets that s where the eggs and larvae are probably hiding . when the vacuum bag is full , seal it in a plastic trash bag and put it in a covered trash container , preferably outside . otherwise , the little buggers can crawl out and make themselves cozy again .
# --Original summary: become friends with your vacuum cleaner .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: vacuum frequently .
# >>Forwards, hidden 600, adam and GREEDY<<: vacuum the eggs
# >>Forwards, rmsprop and BEAM<<: vacuum your house .
# >>Backwards, rmsprop and BEAM<<: vacuum the area .
# >>Backwards: rmsprop and GREEDY<<: vacuum the house
# ===============4108===================
# ======================================
# --Original text: fold the jacket the same way you would fold a t shirt , by first taking the left side and folding it lengthwise inward , approximately inches cm . perform the same step for the right side . fold the sleeve along the folded jacket lines . fold the sleeve over the jacket and then back , so that it lines the jacket fold . the sleeve should be in line with the fold on each side of the jacket . smooth the jacket sleeves downward to remove any wrinkles . leave the jacket in this position on the table .
# --Original summary: fold each side of the jacket inward , toward the middle .
# ---------------------------------------
# >>Forwards, hidden 600, adam and BEAM<<: fold the sleeves .
# >>Forwards, hidden 600, adam and GREEDY<<: fold the sleeves in half
# >>Forwards, rmsprop and BEAM<<: fold the jacket in half .
# >>Backwards, rmsprop and BEAM<<: fold the pants .
# >>Backwards: rmsprop and GREEDY<<: fold the bottom part of the shirt

# %%
choose the ingredients that you need for the recipe .
# Out:
# ['model', 'good', 'behavior', '.']

# %%
l=['model', 'good', 'behavior', '.']

# %%
ref_text = [' '.join(x) for x in y_test_series]

# %%
len(ref_text)
# Out:
# 137342

# %%
len(gen_text)
# Out:
# 10000

# %%
gen_text = [' '.join(x) for x in forward_600_adam_beam['gen_summary']]

# %%
list(set(ref_text) & set(gen_text)) #1715 examples
# Out:
# ['select a chat .',
#  'wash your hair .',
#  'recognize the symptoms of depression .',
#  'practice positive self talk .',
#  'analyze your strengths .',
#  'attend a hearing .',
#  'wait for the glue to dry .',
#  'use a pencil .',
#  'enjoy !',
#  'whisk the dry ingredients .',
#  'communicate .',
#  'gather information about the incident .',
#  'use a humidifier .',
#  'create an outline .',
#  'find a good location .',
#  'research your target market .',
#  'log into your account .',
#  'check the leaves .',
#  'tap settings .',
#  'look for signs of infection .',
#  'add tsp .',
#  'fold the napkin in half .',
#  'wake up early .',
#  'rinse thoroughly .',
#  'use a potato .',
#  'be flexible .',
#  'set limits .',
#  'gather your materials .',
#  'turn on the computer .',
#  'create a new layer .',
#  'launch the facebook app .',
#  'gargle salt water .',
#  'create a rectangle .',
#  'blow up balloons .',
#  'open messenger .',
#  'paint the bow .',
#  'embellish .',
#  'allow the cake to cool .',
#  'pay attention to body language .',
#  'get plenty of rest .',
#  'ask a question .',
#  'practice relaxation techniques .',
#  'enter your email address .',
#  'vaccinate your child .',
#  'change your appearance .',
#  'wear cute clothes .',
#  'earn a master s degree .',
#  'change the water regularly .',
#  'create an apple id .',
#  'create a calendar .',
#  'be stylish .',
#  'use concealer sparingly .',
#  'melt the chocolate .',
#  'make plans .',
#  'use rhubarb .',
#  'install the app .',
#  'open facebook .',
#  'microwave the chocolate mixture .',
#  'strain the liquid .',
#  'protect your skin from the sun .',
#  'eat regularly .',
#  'take a selfie .',
#  'pick a location .',
#  'adjust the temperature .',
#  'bend your knees .',
#  'choose the right tools .',
#  'create a website .',
#  'chill the mixture .',
#  'register your business name .',
#  'stand up for yourself .',
#  'eat well .',
#  'open your iphone’s settings .',
#  'know what to expect .',
#  'disable your passcode .',
#  'apply lotion .',
#  'get surgery .',
#  'preheat the oven to degrees fahrenheit degrees celsius .',
#  'run .',
#  'get a diagnosis .',
#  'show affection .',
#  'take your dog to the vet .',
#  'pay the fee .',
#  'move slowly .',
#  'plan a trip .',
#  'research the company .',
#  'rotate the image .',
#  'socialize your dog .',
#  'ask her out .',
#  'be honest .',
#  'play the game .',
#  'get supplies .',
#  'click download .',
#  'get insurance .',
#  'conduct informational interviews .',
#  'respond to the complaint .',
#  'cut back on alcohol .',
#  'reduce the heat .',
#  'measure your waist .',
#  'remove the laces .',
#  'preheat your oven .',
#  'drink water .',
#  'choose your rope .',
#  'complete the form .',
#  'upload your photo .',
#  'delete files .',
#  'learn about the causes .',
#  'add patterns .',
#  'express your feelings .',
#  'choose healthy snacks .',
#  'be yourself .',
#  'open start .',
#  'click the file menu .',
#  'set realistic goals .',
#  'wait for a response .',
#  'have a scavenger hunt .',
#  'use sunscreen .',
#  'pick a jury .',
#  'provide water .',
#  'open the music app .',
#  'serve warm .',
#  'prepare for your hearing .',
#  'walk .',
#  'send out invitations .',
#  'apply deodorant .',
#  'keep your cell phone charged .',
#  'take a break .',
#  'interact with your audience .',
#  'use credit cards .',
#  'apply the poultice .',
#  'stay positive .',
#  'choose your colors .',
#  'unlock cloud services .',
#  'take your child to the doctor .',
#  'open itunes .',
#  'click the share button .',
#  'create a script .',
#  'stay calm .',
#  'tap notifications .',
#  'work on your flexibility .',
#  'eat salmon .',
#  'tap a story .',
#  'feed your baby .',
#  'make a knot .',
#  'dress to impress .',
#  'curl your hair .',
#  'teach your dog basic commands .',
#  'listen to their response .',
#  'upload files .',
#  'stay hydrated .',
#  'be direct .',
#  'consider hiring an attorney .',
#  'join a team .',
#  'speak up .',
#  'start journaling .',
#  'draw a circle .',
#  'drink tea .',
#  'combine the dry ingredients .',
#  'check for certifications .',
#  'use apple cider vinegar .',
#  'eat garlic .',
#  'choose lean meats .',
#  'challenge negative thoughts .',
#  'think about what you want to say .',
#  'join a professional association .',
#  'sign the agreement .',
#  'draw a straight line .',
#  'open the search bar .',
#  'use transitions .',
#  'release the mouse button .',
#  'fold the paper in half .',
#  'acquire a pot .',
#  'check for leaks .',
#  'remain calm .',
#  'check your calendar .',
#  'talk to your doctor about medication .',
#  'consider other medications .',
#  'eat complex carbohydrates .',
#  'add the finishing touches .',
#  'dry your feet .',
#  'boost your immune system .',
#  'consider surgery .',
#  'know your audience .',
#  'open the snapchat app .',
#  'add the liquids .',
#  'write down your feelings .',
#  'think about your goals .',
#  'use social media .',
#  'tie a knot .',
#  'tell your parents .',
#  'assemble a double boiler .',
#  'practice deep breathing .',
#  'find a venue .',
#  'apply blush .',
#  'take a picture .',
#  'dip the cake balls .',
#  'eat dinner .',
#  'have a conversation .',
#  'choose the right shoes .',
#  'exercise .',
#  'open photoshop .',
#  'find a hobby .',
#  'change the subject .',
#  'turn on your phone .',
#  'get help .',
#  'talk to a therapist .',
#  'eat a balanced diet .',
#  'view the file .',
#  'have fun !',
#  'apply for positions .',
#  'drive safely .',
#  'keep the area clean .',
#  'choose a colour scheme .',
#  'gather your ingredients .',
#  'list your skills .',
#  'open microsoft outlook .',
#  'be punctual .',
#  'keep score .',
#  'let your hair air dry .',
#  'use mirrors .',
#  'get enough protein .',
#  'open the hood .',
#  'wear appropriate clothing .',
#  'draw the nose .',
#  'write your conclusion .',
#  'check for updates .',
#  'freeze the ice cream .',
#  'find a suitable container .',
#  'take time to relax .',
#  'be curious .',
#  'seek medical attention .',
#  'organize your supplies .',
#  'cut the kohlrabi .',
#  'research .',
#  'fill out the application .',
#  'give treats .',
#  'go to the pillow room .',
#  'style your hair .',
#  'turn off the power .',
#  'organize your evidence .',
#  'color .',
#  'draw the eyes .',
#  'blend the ingredients .',
#  'pay attention to your body language .',
#  'enter your personal information .',
#  'start with the basics .',
#  'create a budget .',
#  'move around .',
#  'make sure you have the right equipment .',
#  'choose a bra .',
#  'take the exam .',
#  'pay the fees .',
#  'rinse your hair .',
#  'add color .',
#  'turn off your phone .',
#  'season with salt and pepper .',
#  'download the file .',
#  'recycle .',
#  'schedule an appointment with your veterinarian .',
#  'talk to your friends .',
#  'sell unwanted items .',
#  'fold in the dry ingredients .',
#  'know when to call a doctor .',
#  'collect the pumpkin seeds .',
#  'serve the cake .',
#  'accept yourself .',
#  'add accessories .',
#  'ask for referrals .',
#  'mail the letter .',
#  'view the results .',
#  'make a pattern .',
#  'mix your ingredients .',
#  'find a niche .',
#  'rinse with warm water .',
#  'ask for recommendations .',
#  'choose a name .',
#  'recognize the symptoms .',
#  'watch for symptoms .',
#  'record your video .',
#  'tap save .',
#  'tap the menu button .',
#  'slide the siri button to the on position .',
#  'fill a tub with lukewarm water .',
#  'spay or neuter your cat .',
#  'sign in to your google account .',
#  'flirt .',
#  'serve the other party .',
#  'apply pressure .',
#  'choose your seasoning .',
#  'bathe your cat .',
#  'avoid temptation .',
#  'choose a language .',
#  'calculate the cost .',
#  'attend your hearing .',
#  'use ginger .',
#  'cook for minutes .',
#  'get regular trims .',
#  'check the battery .',
#  'know what you want .',
#  'forgive .',
#  'trim your nails .',
#  'apply the mask to your face .',
#  'tap chats .',
#  'crush the fruit .',
#  'set up parental controls .',
#  'knead the dough .',
#  'don t be afraid to ask questions .',
#  'talk to people .',
#  'vacuum the carpet .',
#  'conclude the letter .',
#  'apply aloe vera .',
#  'open the settings menu .',
#  'start the engine .',
#  'combine the ingredients .',
#  'stand up straight .',
#  'read the label .',
#  'spend time together .',
#  'do strength training .',
#  'line a baking sheet with parchment paper .',
#  'spend time with your friends .',
#  'use mouthwash .',
#  'know the rules .',
#  'vacuum the area .',
#  'breathe .',
#  'ask for support .',
#  'open the file .',
#  'apply for the program .',
#  'present evidence .',
#  'bake the pudding .',
#  'roll the dough into a rectangle .',
#  'ask yourself questions .',
#  'be confident .',
#  'select an image .',
#  'file an appeal .',
#  'ignore undesirable behavior .',
#  'save your money .',
#  'receive the verdict .',
#  'connect your android to your computer .',
#  'be brave .',
#  'assemble the supplies needed .',
#  'reflect on your feelings .',
#  'find a theme .',
#  'use the internet .',
#  'avoid drugs and alcohol .',
#  'make a slip knot .',
#  'spray your hair with hairspray .',
#  'compliment him .',
#  'let the dough rise .',
#  'get into a comfortable position .',
#  'open the file explorer .',
#  'be physically fit .',
#  'make the sauce .',
#  'apply the mask .',
#  'strain the mixture .',
#  'be enthusiastic .',
#  'enter the code .',
#  'turn on your ios device .',
#  'take over the counter pain relievers .',
#  'scroll down and tap mail .',
#  'blow your nose .',
#  'be approachable .',
#  'start the game .',
#  'make the handle .',
#  'insert the needle .',
#  'select a bitmoji .',
#  'open the start menu .',
#  'slice the cake .',
#  'see your doctor .',
#  'blow dry your hair .',
#  'prepare your equipment .',
#  'incorporate strength training .',
#  'compromise .',
#  'highlight your eyes .',
#  'make your bed .',
#  'log in with your google account .',
#  'review your notes .',
#  'open the google play store .',
#  'research the law .',
#  'test the speaker .',
#  'change your diet .',
#  'meet with an attorney .',
#  'add a face .',
#  'wear bright colors .',
#  'make the batter .',
#  'click preferences .',
#  'see your dentist .',
#  'rinse and repeat .',
#  'enter your card information .',
#  'add salt .',
#  'make watermelon lemonade .',
#  'login to your account .',
#  'browse the categories .',
#  'mix the ingredients .',
#  'cleanse your face .',
#  'thank your helper .',
#  'check the warranty .',
#  'be alert .',
#  'gather financial documents .',
#  'gather your supplies .',
#  'take medication .',
#  'apply for internships .',
#  'preview your presentation .',
#  'shop around .',
#  'use flashcards .',
#  'solve the equation .',
#  'apply lipstick .',
#  'adjust your settings .',
#  'open the app store .',
#  'believe in yourself .',
#  'get headshots .',
#  'follow the instructions .',
#  'serve the pancakes .',
#  'visualize success .',
#  'sleep .',
#  'use a deep conditioning treatment .',
#  'think about your personality .',
#  'make a simple syrup .',
#  'open the mail app .',
#  'cook the beans .',
#  'whisk together the dry ingredients .',
#  'apply for the loan .',
#  'arrive early .',
#  'evaluate the integral below .',
#  'repeat as necessary .',
#  'wear compression stockings .',
#  'color the drawing .',
#  'stretch your legs .',
#  'save your changes .',
#  'make sure your dog is comfortable .',
#  'tap apple id .',
#  'cite a book .',
#  'congratulations !',
#  'blot the area .',
#  'apply heat .',
#  'go to the website .',
#  'heat the oil in a large saucepan .',
#  'wash your face .',
#  'season the chicken .',
#  'go to the store .',
#  'invest in stocks .',
#  'click the sharing option .',
#  'provide food and water .',
#  'find a good spot .',
#  'listen to music .',
#  'levels .',
#  'inspect the property .',
#  'show your independence .',
#  'measure the ingredients .',
#  'prepare the soil .',
#  'decorate .',
#  'build a website .',
#  'clean the cage .',
#  'gather relevant documents .',
#  'tap the smiley button .',
#  'eat a healthy breakfast .',
#  'smile .',
#  'add herbs and spices .',
#  'create a playlist .',
#  'find inspiration .',
#  'section your hair .',
#  'click the start button .',
#  'travel to one of the hops patches .',
#  'tap ⚙️ .',
#  'adjust your diet .',
#  'use eye drops .',
#  'wait minutes .',
#  'place the steaks on the grill .',
#  'create a timeline .',
#  'bake for minutes .',
#  'relax .',
#  'understand the process .',
#  'bake the bread .',
#  'communicate effectively .',
#  'follow instructions .',
#  'take your time .',
#  'scoop the mixture .',
#  'wear safety equipment .',
#  'be concise .',
#  'let the cake cool .',
#  'wear the right clothes .',
#  'consider the cost .',
#  'avoid touching your face .',
#  'boil water .',
#  'check your eligibility .',
#  'add the icing .',
#  'create a twitter account .',
#  'clean regularly .',
#  'take biotin supplements .',
#  'rinse your guinea pig .',
#  'create a resume .',
#  'get vaccinated .',
#  'repurpose furniture .',
#  'take a short break .',
#  'wear the right colors .',
#  'ask him out .',
#  'cook rice .',
#  'buy your supplies .',
#  'start writing .',
#  'be spontaneous .',
#  'draw the hair .',
#  'have fun together .',
#  'click on the apple icon .',
#  'add the vanilla extract .',
#  'negotiate a price .',
#  'ask them out .',
#  'agree to disagree .',
#  'clean the area .',
#  'add the whipped cream .',
#  'become an expert .',
#  'color your drawing .',
#  'reinstall windows .',
#  'cook the onions and garlic .',
#  'eat smaller portions .',
#  'be clear about your expectations .',
#  'prepare yourself .',
#  'harvest .',
#  'use tea tree oil .',
#  'take care of your body .',
#  'ask friends and family for recommendations .',
#  'let the meat rest .',
#  'melt the wax .',
#  'be clear .',
#  'tap the hatchery .',
#  'take the licensing exam .',
#  'don t skip meals .',
#  'open your mouth .',
#  'keep your head up .',
#  'cook the chicken .',
#  'ask your child questions .',
#  'use lights .',
#  'choose the right colors .',
#  'eliminate stress .',
#  'add compost to the soil .',
#  'thread your needle .',
#  'eat slowly .',
#  'add the rest of the ingredients .',
#  'you re done .',
#  'eat something .',
#  'be flirtatious .',
#  'decide on a style .',
#  'play board games .',
#  'reduce the heat to low .',
#  'change your clothes .',
#  'bake for to minutes .',
#  'use proper grammar .',
#  'make the dressing .',
#  'use a steam cleaner .',
#  'cook the vegetables .',
#  'rake the patch .',
#  'accessorize .',
#  'learn the vocabulary .',
#  'choose a topic .',
#  'make a list .',
#  'install the program .',
#  'lift your legs .',
#  'lose weight .',
#  'remove the lid .',
#  'call a friend .',
#  'click delete .',
#  'get a blood test .',
#  'file the petition .',
#  'be a good person .',
#  'take a class .',
#  'ask about fees .',
#  'watch for signs of stress .',
#  'discuss treatment options with your vet .',
#  'open the play store .',
#  'serve notice on the defendant .',
#  'eat healthy meals .',
#  'have the defendant served .',
#  'launch the game .',
#  'inhale .',
#  'brush your hair .',
#  'save up .',
#  'dig a trench .',
#  'stay busy .',
#  'use your imagination .',
#  'listen to your gut .',
#  'find solutions .',
#  'kill enemies .',
#  'reduce your sodium intake .',
#  'send a thank you note .',
#  'talk to your boss .',
#  'plan ahead .',
#  'walk to the pot on your kitchen counter .',
#  'draw the circle .',
#  'use a blow dryer .',
#  'be clear about your needs .',
#  'hair .',
#  'open the menu .',
#  'choose your style .',
#  'send a letter .',
#  'spend time with friends and family .',
#  'get a dog .',
#  'click the install button .',
#  'use vinegar .',
#  'heat the milk .',
#  'prepare the ingredients .',
#  'remove the label .',
#  'test the soil .',
#  'open the app .',
#  'prepare the flowers .',
#  'use positive language .',
#  'use dish soap .',
#  'keep training sessions short .',
#  'stay fit .',
#  'take breaks .',
#  'add the pasta .',
#  'apply a cold compress .',
#  'speak clearly .',
#  'take your dog to the veterinarian .',
#  'connect the dots .',
#  'hang out with your friends .',
#  'listen to your body .',
#  'moisturize your face .',
#  'shift your weight .',
#  'complete your forms .',
#  'try cognitive behavioral therapy .',
#  'get a piece of paper .',
#  'eat a healthy diet .',
#  'add ice .',
#  'add the yogurt .',
#  'strain the tea .',
#  'wait for an answer .',
#  'weigh yourself .',
#  'choose a business structure .',
#  'enroll in an obedience class .',
#  'go camping .',
#  'gather the necessary materials .',
#  'find common interests .',
#  'take antibiotics .',
#  'practice self care .',
#  'join a club .',
#  'practice meditation .',
#  'use a satin pillowcase .',
#  'click on save .',
#  'pull your hair back .',
#  'listen for sounds .',
#  'remove from the heat .',
#  'stay current .',
#  'meet the residency requirement .',
#  'finish with hairspray .',
#  'log into your facebook account .',
#  'mix the ingredients together .',
#  'scroll down and tap notes .',
#  'rotate your arm .',
#  'add a title .',
#  'be funny .',
#  'consult a doctor .',
#  'blend until smooth .',
#  'beat the egg .',
#  'add herbs .',
#  'hire an attorney .',
#  'view files .',
#  'click the save button .',
#  'fill in the gaps .',
#  'tap icloud .',
#  'choose the right size .',
#  'brainstorm .',
#  'tap ok .',
#  'ask a friend to help you .',
#  'kill the enemy .',
#  'heat the water .',
#  'conduct market research .',
#  'make a video call .',
#  'speed up .',
#  'pick a venue .',
#  'calculate your maximum heart rate .',
#  'cook the onion .',
#  'get a good night s sleep .',
#  'share your feelings .',
#  'write a headline .',
#  'defeat the monsters .',
#  'read the news .',
#  'remove the wax .',
#  'remove from the oven .',
#  'preheat oven to degrees .',
#  'use baking soda .',
#  'be helpful .',
#  'be kind to others .',
#  'click the messages icon .',
#  'attend a support group .',
#  'research the market .',
#  'check your computer .',
#  'paint the floor .',
#  'enter your pin .',
#  'proofread .',
#  'be creative .',
#  'open the software .',
#  'network .',
#  'prepare for emergencies .',
#  'apply mascara .',
#  'click add account .',
#  'contact the irs .',
#  'identify your skills .',
#  'create a relaxing environment .',
#  'write your letter .',
#  'start early .',
#  'read books .',
#  'practice good hygiene .',
#  'let the area dry .',
#  'get a biopsy .',
#  'use a pill bottle .',
#  'schedule an interview .',
#  'stay safe .',
#  'play with your baby .',
#  'condition your hair .',
#  'take a deep breath .',
#  'turn off your computer .',
#  'search for forms .',
#  'wash your feet .',
#  'eat plenty of vegetables .',
#  'repeat the previous step .',
#  'sit in a comfortable position .',
#  'tap a photo .',
#  'release the ball .',
#  'play music .',
#  'get regular checkups .',
#  'use concealer .',
#  'earn a bachelor s degree .',
#  'get an evaluation .',
#  'decide where you want to go .',
#  'find a mentor .',
#  'try new things .',
#  'look at the big picture .',
#  'open bitmoji .',
#  'set a timer .',
#  'advertise your business .',
#  'wait for the restore process to complete .',
#  'tap done .',
#  'focus on your breath .',
#  'build a support system .',
#  'dress the part .',
#  'keep a dream journal .',
#  'open the settings app .',
#  'watch for signs of infection .',
#  'give yourself time .',
#  'resize the image .',
#  'make a schedule .',
#  'make connections .',
#  'stretch .',
#  'reward your cat .',
#  'draw her eyes .',
#  'submit the form .',
#  'shower .',
#  'seal the bag .',
#  'wash your hands .',
#  'practice self control .',
#  'tap contacts .',
#  'practice yoga .',
#  'reset your password .',
#  'wear a headband .',
#  'testify on your own behalf .',
#  'prepare the mushrooms .',
#  'make a mask .',
#  'click print .',
#  'laugh at yourself .',
#  'put on your outfit .',
#  'get a deck of cards .',
#  'let the stain dry .',
#  'format the text .',
#  'scroll down and tap bluetooth .',
#  'pull the skin tight .',
#  'apply concealer .',
#  'consider the season .',
#  'keep your grades up .',
#  'be encouraging .',
#  'exercise regularly .',
#  'add the dry ingredients .',
#  'cool down .',
#  'apply toner .',
#  'get the right equipment .',
#  'take pain relievers .',
#  'practice active listening .',
#  'consider the consequences .',
#  'understand the benefits .',
#  'consider your options .',
#  'separate the eggs .',
#  'dress for the occasion .',
#  'scroll down and tap keychain .',
#  'don t be aggressive .',
#  'put on gloves .',
#  'print the image .',
#  'ask the right questions .',
#  'maintain eye contact .',
#  'comb your hair .',
#  'use honey .',
#  'work with a mentor .',
#  'gather supporting documents .',
#  'trust your gut .',
#  'separate your hair .',
#  'protect yourself .',
#  'attempt mediation .',
#  'dress appropriately .',
#  'water the plant .',
#  'click the apple menu .',
#  'provide positive reinforcement .',
#  'use rubbing alcohol .',
#  'wear layers .',
#  'evaluate the situation .',
#  'walk away .',
#  'click the gear button in the upper right corner .',
#  'avoid hot water .',
#  'click on restore iphone .',
#  'search online for reviews .',
#  'brainstorm ideas .',
#  'add some glitter .',
#  'continue braiding .',
#  'eat fruits and vegetables .',
#  'open the file menu .',
#  'assemble the items needed .',
#  'open the control panel .',
#  'watch tv .',
#  'consider the benefits .',
#  'select the gradient tool .',
#  'tap the chats tab .',
#  'dress nicely .',
#  'seek counseling .',
#  'don t be greedy .',
#  'jack up the car .',
#  'get tested .',
#  'take a lukewarm bath .',
#  'pick your battles .',
#  'find a counselor .',
#  'save your settings .',
#  'create a character .',
#  'be patient .',
#  'think positively .',
#  'know your limits .',
#  'contact your state bar association .',
#  'aim for the head .',
#  'chop the vegetables .',
#  'click ☰ .',
#  'use a throat spray .',
#  'build a portfolio .',
#  'cut the ribbon .',
#  'do your research .',
#  'get a quote .',
#  'distract yourself .',
#  'do calf raises .',
#  'click on the settings icon .',
#  'call emergency services .',
#  'keep your distance .',
#  'enter your payment information .',
#  'open instagram .',
#  'stay sober .',
#  'choose the right school .',
#  'use a pumice stone .',
#  'avoid negative people .',
#  'compliment them .',
#  'finish the bracelet .',
#  'click the gear icon .',
#  'select the folder .',
#  'use mnemonics .',
#  'wash the shirt .',
#  'back up your data .',
#  'reward yourself .',
#  'publish your post .',
#  'set up an account .',
#  'check references .',
#  'use essential oils .',
#  'format the partition .',
#  'wash your hands thoroughly .',
#  'lock the doors .',
#  'practice relaxation .',
#  'seek support .',
#  'be friendly .',
#  'pause the game .',
#  'preheat the oven .',
#  'use hair spray .',
#  'choose your fabric .',
#  'paint the wood .',
#  'paint the walls .',
#  'plan your route .',
#  'educate yourself .',
#  'communicate with your partner .',
#  'reject perfectionism .',
#  'rinse with water .',
#  'create a business plan .',
#  'remove weeds .',
#  'contact your doctor .',
#  'model good behavior .',
#  'groom your cat .',
#  'challenge yourself .',
#  'assess the situation .',
#  'choose the ingredients that you need for the recipe .',
#  'apply honey .',
#  'wring out the excess water .',
#  'gather the ingredients .',
#  'avoid alcohol .',
#  'use a cold compress .',
#  'exfoliate .',
#  'water regularly .',
#  'make time for intimacy .',
#  'sign up for an account .',
#  'talk to your friends and family .',
#  'talk to your loved one .',
#  'open a web browser .',
#  'study hard .',
#  'know the risk factors .',
#  'click on file .',
#  'click ok .',
#  'create a routine .',
#  'meditate .',
#  'heat the skillet .',
#  'add the cheese .',
#  'type in your email address .',
#  'update your phone .',
#  'fold the paper in half lengthwise .',
#  'tap the back button .',
#  'select a photo .',
#  'remove the outer shell .',
#  'send an email .',
#  'sleep on your back .',
#  'trim your hair .',
#  'buy online .',
#  'water deeply .',
#  'apply primer .',
#  'complete the application .',
#  'ask for help .',
#  'start exercising .',
#  'open the windows .',
#  'read the instructions carefully .',
#  'frost the cake .',
#  'collect the bells .',
#  'floss your teeth .',
#  'offer help .',
#  'click on the start button .',
#  'read online reviews .',
#  'drink more water .',
#  'check the weather .',
#  'open terminal .',
#  'type command prompt into start .',
#  'dress up .',
#  'apply for jobs .',
#  'breathe through your nose .',
#  'confirm your counter decision .',
#  'dance .',
#  'play with your dog .',
#  'pay attention to your surroundings .',
#  'warm up your muscles .',
#  'start walking .',
#  'ship the package .',
#  'interpret the results .',
#  'make a baking soda paste .',
#  'check the temperature .',
#  'lift weights .',
#  'write down your ideas .',
#  'learn a new language .',
#  'teach your dog to sit .',
#  'be affectionate .',
#  'check your tires .',
#  'outline the drawing .',
#  'be humble .',
#  'click on the apple menu .',
#  'calculate the cost of goods sold .',
#  'do your homework .',
#  'listen .',
#  'get a container .',
#  'take your cat to the vet .',
#  'practice mindfulness .',
#  'know that you are not alone .',
#  'spend time outdoors .',
#  'do chest presses .',
#  'click yes .',
#  'take practice tests .',
#  'consider the price .',
#  'add a small amount of water .',
#  'be responsible .',
#  'cook the pancakes .',
#  'blend the dry ingredients .',
#  'check the measurements .',
#  'use “i” statements .',
#  'practice often .',
#  'perform progressive muscle relaxation .',
#  'decide what you want .',
#  'pay the application fee .',
#  'listen to your friend .',
#  'choose a brand .',
#  'click manage .',
#  'eat breakfast .',
#  'offer samples .',
#  'choose the right time .',
#  'click save .',
#  'wear a hat .',
#  'start small .',
#  'manage your weight .',
#  'use olive oil .',
#  'get physical therapy .',
#  'make sure you have the right tools .',
#  'open the command prompt .',
#  'wear sunscreen .',
#  'cook the mushrooms .',
#  'roll the dough .',
#  'eat lean protein .',
#  'use positive reinforcement .',
#  'whisk the eggs .',
#  'view photos .',
#  'ace the interview .',
#  'find a support system .',
#  'eat healthy snacks .',
#  ...]

# %%
gen_text.index('create a fairy light .')
# Out:
# 0

# %%
for i in range(len(gen_text)):
    if gen_text[i]==ref_text[i]:
        print(gen_text[i])
        print(i)
        print('------------')
# Out:
# tap ☰ .
# 32
# ------------
# meditate .
# 55
# ------------
# tap icloud .
# 88
# ------------
# restart your computer .
# 107
# ------------
# join a support group .
# 109
# ------------
# place the steaks on the grill .
# 169
# ------------
# be confident .
# 179
# ------------
# choose the ingredients that you need for the recipe .
# 199
# ------------
# measure the ingredients .
# 273
# ------------
# see your veterinarian .
# 301
# ------------
# decide what you want to do with the pouches .
# 306
# ------------
# accessorize .
# 307
# ------------
# offer samples .
# 316
# ------------
# let the person air dry .
# 354
# ------------
# dip the cake balls .
# 393
# ------------
# stand up straight .
# 428
# ------------
# eat breakfast .
# 451
# ------------
# stay calm .
# 454
# ------------
# open your iphone s photos app .
# 464
# ------------
# microwave the chocolate mixture .
# 486
# ------------
# use hair spray .
# 554
# ------------
# take pictures .
# 587
# ------------
# open your iphone s settings .
# 772
# ------------
# plant trees .
# 793
# ------------
# apply the shampoo .
# 838
# ------------
# purchase equipment .
# 899
# ------------
# start early .
# 935
# ------------
# aim for the head .
# 945
# ------------
# keep a journal .
# 954
# ------------
# serve .
# 987
# ------------
# watch movies .
# 1077
# ------------
# blow up balloons .
# 1148
# ------------
# recognize the symptoms .
# 1193
# ------------
# wear layers .
# 1278
# ------------
# eat more fiber .
# 1311
# ------------
# play with your cat .
# 1432
# ------------
# file your complaint .
# 1462
# ------------
# check for a fever .
# 1487
# ------------
# pay the fee .
# 1515
# ------------
# collect your winnings .
# 1551
# ------------
# open photoshop .
# 1593
# ------------
# brush your teeth .
# 1616
# ------------
# eat regularly .
# 1707
# ------------
# ask questions .
# 1738
# ------------
# collect coins .
# 1762
# ------------
# declare a winner .
# 1849
# ------------
# go to school .
# 1884
# ------------
# make a list .
# 1934
# ------------
# pay the application fee .
# 1946
# ------------
# open safari .
# 1955
# ------------
# install the roof .
# 1998
# ------------
# reassemble the keyboard .
# 2085
# ------------
# scoop the mixture .
# 2136
# ------------
# test the speaker .
# 2188
# ------------
# serve .
# 2214
# ------------
# assemble the items needed .
# 2251
# ------------
# testify on your own behalf .
# 2344
# ------------
# fill out the application .
# 2418
# ------------
# take a fiber supplement .
# 2438
# ------------
# hire a lawyer .
# 2524
# ------------
# take care of yourself .
# 2587
# ------------
# be yourself .
# 2630
# ------------
# file your proof of service .
# 2657
# ------------
# be confident .
# 2689
# ------------
# serve .
# 2832
# ------------
# ask for help .
# 2835
# ------------
# scroll down and tap settings .
# 2859
# ------------
# join a support group .
# 2876
# ------------
# get a piece of paper .
# 2941
# ------------
# choose a target .
# 2969
# ------------
# provide positive reinforcement .
# 3047
# ------------
# serve the other party .
# 3054
# ------------
# log in .
# 3068
# ------------
# let the dough rise .
# 3114
# ------------
# smile .
# 3210
# ------------
# draw her eyelashes .
# 3215
# ------------
# sign in with your apple id .
# 3288
# ------------
# clean the closet .
# 3374
# ------------
# set a timer .
# 3392
# ------------
# open your iphone’s settings .
# 3396
# ------------
# make the dressing .
# 3404
# ------------
# cook the onions and garlic .
# 3428
# ------------
# schedule your exam .
# 3455
# ------------
# choose a size .
# 3465
# ------------
# mix the ingredients together .
# 3477
# ------------
# lift weights .
# 3491
# ------------
# preheat the oven .
# 3497
# ------------
# remain calm .
# 3498
# ------------
# open instagram .
# 3509
# ------------
# enter your payment information .
# 3574
# ------------
# quit smoking .
# 3613
# ------------
# travel to one of the hops patches .
# 3643
# ------------
# restate your thesis .
# 3683
# ------------
# tap the back button .
# 3700
# ------------
# brush your dog’s teeth .
# 3762
# ------------
# gather your materials .
# 3786
# ------------
# connect your ipod to your computer .
# 3807
# ------------
# serve .
# 3861
# ------------
# open the mail app .
# 3911
# ------------
# quit smoking .
# 3947
# ------------
# look for signs of stress .
# 3965
# ------------
# model good behavior .
# 4007
# ------------
# cook the pancakes .
# 4025
# ------------
# state the purchase price .
# 4128
# ------------
# delete files .
# 4164
# ------------
# highlight your eyes .
# 4207
# ------------
# use your imagination .
# 4310
# ------------
# wear clothes that fit .
# 4333
# ------------
# gather your supplies .
# 4489
# ------------
# identify your target market .
# 4572
# ------------
# type command prompt into start .
# 4573
# ------------
# find a mentor .
# 4623
# ------------
# submit the form .
# 4690
# ------------
# volunteer .
# 4722
# ------------
# gather your supplies .
# 4731
# ------------
# rake the patch .
# 4897
# ------------
# wait for the driver to arrive .
# 4920
# ------------
# consider arbitration .
# 5011
# ------------
# practice good hygiene .
# 5067
# ------------
# get a medical exam .
# 5070
# ------------
# change your clothes .
# 5087
# ------------
# jack up the car .
# 5121
# ------------
# open microsoft word .
# 5131
# ------------
# ground yourself .
# 5147
# ------------
# be respectful .
# 5179
# ------------
# tap ☰ .
# 5207
# ------------
# record yourself .
# 5213
# ------------
# rebuild trust .
# 5220
# ------------
# reward yourself .
# 5226
# ------------
# launch google chrome .
# 5253
# ------------
# log in .
# 5318
# ------------
# apply mascara .
# 5351
# ------------
# heat tbsp .
# 5370
# ------------
# eat slowly .
# 5385
# ------------
# remove the cheesecake from the pan .
# 5411
# ------------
# reward yourself .
# 5453
# ------------
# cook the bacon .
# 5621
# ------------
# ventilate the area .
# 5671
# ------------
# unlock your iphone .
# 5691
# ------------
# take practice tests .
# 5850
# ------------
# serve .
# 5859
# ------------
# season the corn .
# 5928
# ------------
# open the play store .
# 5989
# ------------
# click ⚙️ .
# 6061
# ------------
# be friendly .
# 6089
# ------------
# join a support group .
# 6201
# ------------
# see your doctor .
# 6339
# ------------
# tap the hatchery .
# 6353
# ------------
# send your message .
# 6355
# ------------
# keep score .
# 6411
# ------------
# apply heat .
# 6414
# ------------
# join a study group .
# 6428
# ------------
# add the pasta .
# 6436
# ------------
# smile .
# 6447
# ------------
# defend against a motion for summary judgment .
# 6475
# ------------
# melt the wax .
# 6583
# ------------
# fertilize the lawn .
# 6613
# ------------
# open start .
# 6634
# ------------
# slice the cake .
# 6641
# ------------
# exercise regularly .
# 6644
# ------------
# launch google earth .
# 6674
# ------------
# create a schedule .
# 6725
# ------------
# dry the hamster .
# 6778
# ------------
# add the remaining ingredients .
# 6808
# ------------
# melt the butter .
# 6863
# ------------
# stretch .
# 6913
# ------------
# sign in .
# 7041
# ------------
# take public transit .
# 7047
# ------------
# click on the apple menu .
# 7049
# ------------
# update your phone .
# 7107
# ------------
# crush the fruit .
# 7164
# ------------
# eat dinner .
# 7184
# ------------
# open your iphone s settings .
# 7253
# ------------
# tap ☰ .
# 7261
# ------------
# create an account .
# 7274
# ------------
# check for updates .
# 7306
# ------------
# brush your teeth .
# 7308
# ------------
# confirm your counter decision .
# 7334
# ------------
# list your skills .
# 7356
# ------------
# smile .
# 7402
# ------------
# focus on the positive .
# 7425
# ------------
# apply the mask .
# 7432
# ------------
# quit smoking .
# 7447
# ------------
# take notes .
# 7449
# ------------
# select a photo .
# 7456
# ------------
# open a web browser .
# 7536
# ------------
# apply aloe vera .
# 7625
# ------------
# volunteer .
# 7649
# ------------
# call the police .
# 7703
# ------------
# open your iphone s settings .
# 7758
# ------------
# let your hair air dry .
# 7804
# ------------
# do burpees .
# 7819
# ------------
# listen to music .
# 7824
# ------------
# acquire a pot .
# 7999
# ------------
# provide nesting materials .
# 8031
# ------------
# unlock cloud services .
# 8070
# ------------
# create a playlist .
# 8084
# ------------
# check for hair loss .
# 8090
# ------------
# tap ☰ .
# 8116
# ------------
# click on trackpad .
# 8151
# ------------
# select a theme .
# 8159
# ------------
# practice .
# 8164
# ------------
# be confident .
# 8217
# ------------
# eat salmon .
# 8238
# ------------
# land .
# 8265
# ------------
# open the control panel .
# 8279
# ------------
# collect the bells .
# 8321
# ------------
# practice mindfulness .
# 8324
# ------------
# walk away .
# 8361
# ------------
# finalize your design .
# 8374
# ------------
# open your mouth .
# 8446
# ------------
# call a friend .
# 8528
# ------------
# section off your hair .
# 8565
# ------------
# heat the oil .
# 8577
# ------------
# create a rectangle .
# 8652
# ------------
# urinate frequently .
# 8668
# ------------
# add the icing .
# 8710
# ------------
# launch the facebook app .
# 8711
# ------------
# assemble a double boiler .
# 8724
# ------------
# serve the other party .
# 8766
# ------------
# reward yourself .
# 8787
# ------------
# conduct informational interviews .
# 8788
# ------------
# select a bitmoji .
# 8824
# ------------
# cut the grapefruit in half .
# 8915
# ------------
# ask questions .
# 8988
# ------------
# verify your account .
# 9046
# ------------
# steam the hat .
# 9048
# ------------
# take antibiotics .
# 9085
# ------------
# serve .
# 9087
# ------------
# file your petition .
# 9123
# ------------
# gather your materials .
# 9125
# ------------
# thread the needle .
# 9380
# ------------
# open the command prompt .
# 9416
# ------------
# start early .
# 9541
# ------------
# power on your iphone .
# 9587
# ------------
# wear compression stockings .
# 9638
# ------------
# be polite .
# 9701
# ------------
# choose your seasoning .
# 9753
# ------------
# serve the other party .
# 9812
# ------------
# cook the beans .
# 9926
# ------------
# disable the cheats .
# 9960
# ------------
# ask questions .
# 9969
# ------------

# %% [markdown]
# ## Observations:
#
# * longer text (i.e. batch 4003, 4008): generated summaries tend to be a bit like gibberish or too short to give any real meaning. This is perhaps due to the fact that texts were cut to be < 100 words. However, if the text was well written (i.e. batch 4027; "well-written" is definitely subjective here), results are still quite legible and understandable to the human brain.
# * medium text (i.e. batch 4004, 4005, 4006, 4007, 4013, 4033, 4034,4040): summaries may not reflect original summary, but do provide good representation from a human point of view.
# * forward with hidden 600 obviously had more parameters to learn, but learned fairly impressive results (i.e. batch 4011, 4012, 4017).
# * It would seem that the original text themselves must also provide enough length for the encoder-decoder to learn anything meaningful and spit out a summary (i.e. batch 4016, 4025).
# * Batch 4045 shows a test summary with just 1 word. This is something that we should have looked through and caught when cleaning the dataset.

# %%
# how are the scores split between lengths of summaries? 

# what is the general distribution of the text data (provided text)? 
len_text = []
for i in range(0,len(x_test_series)): 
    len_text.append(len(x_test_series[i]))
    
fig, ax = plt.subplots(figsize=(10,8))
sns.distplot(len_text, ax=ax, bins=300).set_title('Distribution of text lengths')
plt.xlabel('Length of text')
plt.xlim([0,500])
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# observe how rouge scores fluctuate based on text length provided 
# let's do some buckets: < 50 words, 50 - 100 words, > 100 words 


# worth noting here that this is based on the cleaned up text; we would have to run the encoder 
# to get the actual encoded text (which would be less than 100 words) 

lthan50 = [] 
bt50and100 = [] 
gthan100 = [] 
for i in range(0, len(len_text)): 
    if len_text[i]<=50: 
        lthan50.append(i)
    elif len_text[i]>50 and len_text[i]<=100: 
        bt50and100.append(i)
    else: 
        gthan100.append(i)

def getscore(index_holder,df): 
    r = np.nanmean(df[df.index.isin(index_holder)]['recall'])
    p = np.nanmean(df[df.index.isin(index_holder)]['precision'])
    f = np.nanmean(df[df.index.isin(index_holder)]['f1score'])
    return(r,p,f)

lthan50_all = []
lthan50_all.append(getscore(lthan50, forward_600_adam_beam))
lthan50_all.append(getscore(lthan50, forward_600_adam_greedy))
lthan50_all.append(getscore(lthan50, rms_forward_beam))
lthan50_all.append(getscore(lthan50, rms_backward_beam))
lthan50_all.append(getscore(lthan50, rms_backward_greedy))

lthan50_all_df = pd.DataFrame(lthan50_all)
lthan50_all_df.columns = ['recall','precision','f1score']
lthan50_all_df.index = ['f_adam_beam','f_adam_greedy','rms_forward_beam','rms_backward_beam','rms_backward_greedy']

bt50and100_all = []
bt50and100_all.append(getscore(bt50and100, forward_600_adam_beam))
bt50and100_all.append(getscore(bt50and100, forward_600_adam_greedy))
bt50and100_all.append(getscore(bt50and100, rms_forward_beam))
bt50and100_all.append(getscore(bt50and100, rms_backward_beam))
bt50and100_all.append(getscore(bt50and100, rms_backward_greedy))

bt50and100_all_df = pd.DataFrame(bt50and100_all)
bt50and100_all_df.columns = ['recall','precision','f1score']
bt50and100_all_df.index = ['f_adam_beam','f_adam_greedy','rms_forward_beam','rms_backward_beam','rms_backward_greedy']

gthan100_all = []
gthan100_all.append(getscore(gthan100, forward_600_adam_beam))
gthan100_all.append(getscore(gthan100, forward_600_adam_greedy))
gthan100_all.append(getscore(gthan100, rms_forward_beam))
gthan100_all.append(getscore(gthan100, rms_backward_beam))
gthan100_all.append(getscore(gthan100, rms_backward_greedy))

gthan100_all_df = pd.DataFrame(gthan100_all)
gthan100_all_df.columns = ['recall','precision','f1score']
gthan100_all_df.index = ['f_adam_beam','f_adam_greedy','rms_forward_beam','rms_backward_beam','rms_backward_greedy']

# %%
lthan50_all_df
# Out:
#                        recall  precision   f1score
# f_adam_beam          0.188621   0.231249  0.190249
# f_adam_greedy        0.209822   0.280921  0.218318
# rms_forward_beam     0.180389   0.223579  0.182962
# rms_backward_beam    0.165148   0.212025  0.169681
# rms_backward_greedy  0.190864   0.261933  0.200772

# %%
bt50and100_all_df
# Notice how rms_backward_beam vs. rms_backward_greedy do not differ much based on the text length 
# (especially lthan50 or bt50and100). 

# Overall in general, it seems like all experiments do almost roughly the same as long as the original text 
# was not too long. 

# It does look like the forward_600_adam_greedy, however, did the best in texts between 50 and 100 words long.
# Out:
#                        recall  precision   f1score
# f_adam_beam          0.201386   0.233191  0.202078
# f_adam_greedy        0.220962   0.285060  0.231243
# rms_forward_beam     0.199807   0.228884  0.199320
# rms_backward_beam    0.166494   0.205024  0.171980
# rms_backward_greedy  0.192822   0.263672  0.206771

# %%
gthan100_all_df
# Notice how across the board, if the original text provided was greater than 100, 
# we see a decrease in all metrics for all of our experiments
# Out:
#                        recall  precision   f1score
# f_adam_beam          0.161829   0.182121  0.161472
# f_adam_greedy        0.170681   0.220156  0.179021
# rms_forward_beam     0.153154   0.171064  0.151206
# rms_backward_beam    0.141993   0.165322  0.143575
# rms_backward_greedy  0.157686   0.209627  0.167381
